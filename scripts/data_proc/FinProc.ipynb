# %%
import pandas as pd

# %%
rcc_04_labelwise_nan_avg = pd.read_csv(r"rcc04/labelwise_nans_avg_labelled_rcc04.csv")
rcc_05_labelwise_nan_avg = pd.read_csv(r"rcc05/labelwise_nans_avg_labelled_rcc05.csv")

# %%
rcc_04_labelwise_nan_avg.head(3)
# Out:
#    max_betweenness_centrality  avg_betweenness_centrality  \
# 0                    0.364169                    0.010538
# 1                    0.329659                    0.010094
# 2                    0.287193                    0.010885
#
#    max_load_centrality  avg_load_centrality  max_closeness_centrality  \
# 0             0.362256             0.010538                  0.427683
# 1             0.327756             0.010094                  0.417367
# 2             0.287539             0.010885                  0.420886
#
#    avg_closeness_centrality  max_harmonic_centrality  avg_harmonic_centrality  \
# 0                  0.267457               144.483333                80.352695
# 1                  0.258058               149.716667                83.660187
# 2                  0.266156               133.366667                77.097277
#
#    max_degree_centrality  avg_degree_centrality  ...  W-Prefix  A-Dup  W-Dup  \
# ...

# %%
rcc_05_labelwise_nan_avg.head(3)
# Out:
#    max_betweenness_centrality  avg_betweenness_centrality  \
# 0                    0.588307                    0.041385
# 1                    0.567988                    0.054987
# 2                    0.508901                    0.037952
#
#    max_load_centrality  avg_load_centrality  max_closeness_centrality  \
# 0             0.587355             0.041385                  0.390244
# 1             0.566922             0.054987                  0.334951
# 2             0.507755             0.037952                  0.363310
#
#    avg_closeness_centrality  max_harmonic_centrality  avg_harmonic_centrality  \
# 0                  0.244727                39.216667                22.690292
# 1                  0.221574                31.602381                18.416573
# 2                  0.226548                40.783333                23.704038
#
#    max_degree_centrality  avg_degree_centrality  ...  W-Prefix  A-Dup  W-Dup  \
# ...

# %%
rcc_04_labelwise_nan_avg.to_csv(r"final_csvs/type1_labelwise_nans_avg_labelled_rcc04.csv", index=False)
rcc_05_labelwise_nan_avg.to_csv(r"final_csvs/type1_labelwise_nans_avg_labelled_rcc05.csv", index=False)

# %%
merged_labelwise_nan_avg = pd.concat([rcc_04_labelwise_nan_avg, rcc_05_labelwise_nan_avg], ignore_index=True)

# %%
merged_labelwise_nan_avg.head()
# Out:
#    max_betweenness_centrality  avg_betweenness_centrality  \
# 0                    0.364169                    0.010538
# 1                    0.329659                    0.010094
# 2                    0.287193                    0.010885
# 3                    0.354570                    0.010829
# 4                    0.248746                    0.009681
#
#    max_load_centrality  avg_load_centrality  max_closeness_centrality  \
# 0             0.362256             0.010538                  0.427683
# 1             0.327756             0.010094                  0.417367
# 2             0.287539             0.010885                  0.420886
# 3             0.351908             0.010829                  0.431856
# 4             0.247404             0.009681                  0.393070
#
#    avg_closeness_centrality  max_harmonic_centrality  avg_harmonic_centrality  \
# 0                  0.267457               144.483333                80.352695
# ...

# %%
merged_labelwise_nan_avg.to_csv("final_csvs/type1_labelwise_nans_avg_labelled_merged.csv", index=False)

# %% [markdown]
# ## Padded

# %%
adj_2w_pad_clean_04 = pd.read_csv(r"rcc04/adj_2w_pad_clean.csv")
adj_2w_pad_clean_05 = pd.read_csv(r"rcc05/adj_2w_pad_clean.csv")

# %%
adj_2w_pad_clean_04 = adj_2w_pad_clean_04.drop(["Unnamed: 0"], axis=1)
adj_2w_pad_clean_04
# Out:
#       prev_max_betweenness_centrality  prev_avg_betweenness_centrality  \
# 0                            0.364169                         0.010538
# 1                            0.329659                         0.010094
# 2                            0.287193                         0.010885
# 3                            0.354570                         0.010829
# 4                            0.248746                         0.009681
# ...                               ...                              ...
# 5177                         0.278057                         0.008665
# 5178                         0.255629                         0.008422
# 5179                         0.310274                         0.009930
# 5180                         0.248965                         0.007801
# 5181                         0.266013                         0.010341
#
#       prev_max_load_centrality  prev_avg_load_centrality  \
# ...

# %%
adj_2w_pad_clean_04.to_csv(r"final_csvs/type_2_adj_2w_pad_clean_rcc04.csv", index=False)

# %%
adj_2w_pad_clean_05 = adj_2w_pad_clean_05.drop(["Unnamed: 0"], axis=1)
adj_2w_pad_clean_05
# Out:
#       prev_max_betweenness_centrality  prev_avg_betweenness_centrality  \
# 0                            0.588307                         0.041385
# 1                            0.567988                         0.054987
# 2                            0.508901                         0.037952
# 3                            0.515440                         0.041435
# 4                            0.370068                         0.026459
# ...                               ...                              ...
# 5177                         0.329677                         0.008393
# 5178                         0.278992                         0.007463
# 5179                         0.296787                         0.008975
# 5180                         0.246267                         0.008761
# 5181                         0.269660                         0.010471
#
#       prev_max_load_centrality  prev_avg_load_centrality  \
# ...

# %%
adj_2w_pad_clean_05.to_csv(r"final_csvs/type_2_adj_2w_pad_clean_rcc05.csv", index=False)

# %%
merged_adj_2w_pad_clean = pd.concat([adj_2w_pad_clean_04, adj_2w_pad_clean_05], ignore_index=True)

# %%
merged_adj_2w_pad_clean
merged_adj_2w_pad_clean.to_csv(r"final_csvs/type_2_adj_2w_pad_clean_merged.csv")

# %% [markdown]
# ## 1D-2W

# %%
oneD_2W_df_clean_04 = pd.read_csv(r"rcc04/oneD_2W_df_clean.csv")
oneD_2W_df_clean_05 = pd.read_csv(r"rcc05/oneD_2W_df_clean.csv")

# %%
oneD_2W_df_clean_04 = oneD_2W_df_clean_04.drop(["Unnamed: 0"], axis=1)
oneD_2W_df_clean_04.to_csv("final_csvs/type_3_oneD_2W_df_clean_rcc04.csv", index=False)

# %%
oneD_2W_df_clean_05 = oneD_2W_df_clean_05.drop(["Unnamed: 0"], axis=1)
oneD_2W_df_clean_05.to_csv("final_csvs/type_3_oneD_2W_df_clean_rcc05.csv", index=False)

# %%
merged_oneD_2W_df_clean = pd.concat([oneD_2W_df_clean_04, oneD_2W_df_clean_05], ignore_index=True)

# %%
merged_oneD_2W_df_clean
# Out:
#        prev_max_betweenness_centrality  prev_avg_betweenness_centrality  \
# 0                             0.323575                         0.011523
# 1                             0.323575                         0.011523
# 2                             0.323575                         0.011523
# 3                             0.323575                         0.011523
# 4                             0.323575                         0.011523
# ...                                ...                              ...
# 10363                         0.252221                         0.006635
# 10364                         0.252221                         0.006635
# 10365                         0.252221                         0.006635
# 10366                         0.252221                         0.006635
# 10367                         0.252221                         0.006635
#
#        prev_max_load_centrality  prev_avg_load_centrality  \
# ...

# %%
merged_oneD_2W_df_clean.to_csv("final_csvs/type_3_oneD_2W_df_clean_merged.csv", index=False)

# %% [markdown]
# ## 2-day

# %%
twoD_2W_df_clean_04 = pd.read_csv(r"rcc04/twoD_2W_df_clean.csv")
twoD_2W_df_clean_05 = pd.read_csv(r"rcc05/twoD_2W_df_clean.csv")

# %%
twoD_2W_df_clean_04 = twoD_2W_df_clean_04.drop(["Unnamed: 0"], axis=1)
twoD_2W_df_clean_04.to_csv("final_csvs/type4_twoD_2W_df_clean_04.csv", index=False)

# %%
twoD_2W_df_clean_05 = twoD_2W_df_clean_05.drop(["Unnamed: 0"], axis=1)
twoD_2W_df_clean_05.to_csv("final_csvs/type4_twoD_2W_df_clean_05.csv", index=False)

# %%
twoD_2W_df_clean_04
# Out:
#       prev_max_betweenness_centrality  prev_avg_betweenness_centrality  \
# 0                            0.323575                         0.011523
# 1                            0.323575                         0.011523
# 2                            0.323575                         0.011523
# 3                            0.323575                         0.011523
# 4                            0.323575                         0.011523
# ...                               ...                              ...
# 5179                         0.292893                         0.006070
# 5180                         0.292893                         0.006070
# 5181                         0.292893                         0.006070
# 5182                         0.292893                         0.006070
# 5183                         0.292893                         0.006070
#
#       prev_max_load_centrality  prev_avg_load_centrality  \
# ...

# %%
twoD_2W_df_clean_05
# Out:
#       prev_max_betweenness_centrality  prev_avg_betweenness_centrality  \
# 0                            0.369132                         0.014060
# 1                            0.369132                         0.014060
# 2                            0.369132                         0.014060
# 3                            0.369132                         0.014060
# 4                            0.369132                         0.014060
# ...                               ...                              ...
# 5179                         0.246057                         0.006559
# 5180                         0.246057                         0.006559
# 5181                         0.246057                         0.006559
# 5182                         0.246057                         0.006559
# 5183                         0.246057                         0.006559
#
#       prev_max_load_centrality  prev_avg_load_centrality  \
# ...

# %%
merged_twoD_2W_df_clean = pd.concat([twoD_2W_df_clean_04, twoD_2W_df_clean_05], ignore_index=True)

# %%
merged_twoD_2W_df_clean
# Out:
#        prev_max_betweenness_centrality  prev_avg_betweenness_centrality  \
# 0                             0.323575                         0.011523
# 1                             0.323575                         0.011523
# 2                             0.323575                         0.011523
# 3                             0.323575                         0.011523
# 4                             0.323575                         0.011523
# ...                                ...                              ...
# 10363                         0.246057                         0.006559
# 10364                         0.246057                         0.006559
# 10365                         0.246057                         0.006559
# 10366                         0.246057                         0.006559
# 10367                         0.246057                         0.006559
#
#        prev_max_load_centrality  prev_avg_load_centrality  \
# ...

# %%
merged_twoD_2W_df_clean.to_csv(r"final_csvs/type4_twoD_2W_df_clean_merged.csv", index=False)
