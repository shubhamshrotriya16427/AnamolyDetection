# %%
import pandas as pd

# %%
main_df = pd.read_csv(r"/Users/adityamagarde/Documents/UCR/CS240_NR/AnamolyDetection/data/csvs/final_csvs/type1_labelwise_nans_avg_labelled_merged.csv")

# %%
main_df
# Out:
#        max_betweenness_centrality  avg_betweenness_centrality  \
# 0                        0.364169                    0.010538
# 1                        0.329659                    0.010094
# 2                        0.287193                    0.010885
# 3                        0.354570                    0.010829
# 4                        0.248746                    0.009681
# ...                           ...                         ...
# 10363                    0.296787                    0.008975
# 10364                    0.246267                    0.008761
# 10365                    0.269660                    0.010471
# 10366                    0.235079                    0.010053
# 10367                    0.227344                    0.009405
#
#        max_load_centrality  avg_load_centrality  max_closeness_centrality  \
# 0                 0.362256             0.010538                  0.427683
# ...
