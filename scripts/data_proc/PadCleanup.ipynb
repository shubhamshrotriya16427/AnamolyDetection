# %%
import pandas as pd

# %% [markdown]
# ## adj_2w_pad CLEANUP

# %%
adj_2w_pad_unclean = pd.read_csv(r"adj_2w_pad_unclean.csv")

# %%
adj_2w_pad_unclean.head()
# Out:
#    prev_max_betweenness_centrality  prev_avg_betweenness_centrality  \
# 0                         0.588307                         0.041385
# 1                         0.567988                         0.054987
# 2                         0.508901                         0.037952
# 3                         0.515440                         0.041435
# 4                         0.370068                         0.026459
#
#    prev_max_load_centrality  prev_avg_load_centrality  \
# 0                  0.587355                  0.041385
# 1                  0.566922                  0.054987
# 2                  0.507755                  0.037952
# 3                  0.511352                  0.041435
# 4                  0.369403                  0.026459
#
#    prev_max_closeness_centrality  prev_avg_closeness_centrality  \
# 0                       0.390244                       0.244727
# 1                       0.334951                       0.221574
# ...

# %%
adj_2w_pad_unclean.columns.to_list()
# Out:
# ['prev_max_betweenness_centrality',
#  'prev_avg_betweenness_centrality',
#  'prev_max_load_centrality',
#  'prev_avg_load_centrality',
#  'prev_max_closeness_centrality',
#  'prev_avg_closeness_centrality',
#  'prev_max_harmonic_centrality',
#  'prev_avg_harmonic_centrality',
#  'prev_max_degree_centrality',
#  'prev_avg_degree_centrality',
#  'prev_max_eigenvector_centrality',
#  'prev_avg_eigenvector_centrality',
#  'prev_max_number_of_cliques',
#  'prev_avg_number_of_cliques',
#  'prev_max_size_of_cliques',
#  'prev_avg_size_of_cliques',
#  'prev_max_clustering_coefficent',
#  'prev_avg_clustering_coefficent',
#  'prev_max_traingle_coefficient',
#  'prev_avg_traingle_coefficient',
#  'prev_max_square_clustering_coefficient',
#  'prev_avg_square_clustering_coefficient',
#  'prev_max_avg_neighbour_degree',
#  'prev_avg_avg_neighbour_degree',
#  'prev_max_eccentricity',
#  'prev_avg_eccentricity',
#  'prev_Updates',
#  'prev_A-Updates',
#  'prev_W-Updates',
#  'prev_A-Prefix',
# ...

# %%
columns_to_eliminate = ['prev_date', 'prev_time', 'prev_is_anamoly', 'next_date', 'next_time', 'next_is_anamoly']

# %%
adj_2w_pad_clean = adj_2w_pad_unclean.drop(columns_to_eliminate, axis=1)

# %%
adj_2w_pad_clean.head()
# Out:
#    prev_max_betweenness_centrality  prev_avg_betweenness_centrality  \
# 0                         0.588307                         0.041385
# 1                         0.567988                         0.054987
# 2                         0.508901                         0.037952
# 3                         0.515440                         0.041435
# 4                         0.370068                         0.026459
#
#    prev_max_load_centrality  prev_avg_load_centrality  \
# 0                  0.587355                  0.041385
# 1                  0.566922                  0.054987
# 2                  0.507755                  0.037952
# 3                  0.511352                  0.041435
# 4                  0.369403                  0.026459
#
#    prev_max_closeness_centrality  prev_avg_closeness_centrality  \
# 0                       0.390244                       0.244727
# 1                       0.334951                       0.221574
# ...

# %% [markdown]
# ## 1D_2W_pad CLEANUP

# %%
oneD_2W_pad_unclean = pd.read_csv(r"oneD_2W_df_unclean.csv")

# %%
oneD_2W_pad_unclean.head()
# Out:
#    Unnamed: 0  prev_max_betweenness_centrality  \
# 0           0                         0.369132
# 1           1                         0.369132
# 2           2                         0.369132
# 3           3                         0.369132
# 4           4                         0.369132
#
#    prev_avg_betweenness_centrality  prev_max_load_centrality  \
# 0                          0.01406                  0.367384
# 1                          0.01406                  0.367384
# 2                          0.01406                  0.367384
# 3                          0.01406                  0.367384
# 4                          0.01406                  0.367384
#
#    prev_avg_load_centrality  prev_max_closeness_centrality  \
# 0                   0.01406                       0.395384
# 1                   0.01406                       0.395384
# 2                   0.01406                       0.395384
# 3                   0.01406                       0.395384
# ...

# %%
oneD_2W_pad_unclean.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'prev_max_betweenness_centrality',
#  'prev_avg_betweenness_centrality',
#  'prev_max_load_centrality',
#  'prev_avg_load_centrality',
#  'prev_max_closeness_centrality',
#  'prev_avg_closeness_centrality',
#  'prev_max_harmonic_centrality',
#  'prev_avg_harmonic_centrality',
#  'prev_max_degree_centrality',
#  'prev_avg_degree_centrality',
#  'prev_max_eigenvector_centrality',
#  'prev_avg_eigenvector_centrality',
#  'prev_max_number_of_cliques',
#  'prev_avg_number_of_cliques',
#  'prev_max_size_of_cliques',
#  'prev_avg_size_of_cliques',
#  'prev_max_clustering_coefficent',
#  'prev_avg_clustering_coefficent',
#  'prev_max_traingle_coefficient',
#  'prev_avg_traingle_coefficient',
#  'prev_max_square_clustering_coefficient',
#  'prev_avg_square_clustering_coefficient',
#  'prev_max_avg_neighbour_degree',
#  'prev_avg_avg_neighbour_degree',
#  'prev_max_eccentricity',
#  'prev_avg_eccentricity',
#  'prev_Updates',
#  'prev_A-Updates',
#  'prev_W-Updates',
# ...

# %%
# Comparision
adj_cols = set(adj_2w_pad_unclean.columns.to_list())
oned_cols = set(oneD_2W_pad_unclean.columns.to_list())

# %%
len(adj_cols), len(oned_cols)
# Out:
# (120, 117)

# %%
adj_cols - oned_cols
# Out:
# {'next_date', 'next_time', 'prev_date', 'prev_time'}

# %%
od_cols_to_remove = ['Unnamed: 0', 'prev_is_anamoly', 'next_is_anamoly']

# %%
oneD_2W_pad_clean = oneD_2W_pad_unclean.drop(od_cols_to_remove, axis=1)

# %%
oneD_2W_pad_clean.head()
# Out:
#    prev_max_betweenness_centrality  prev_avg_betweenness_centrality  \
# 0                         0.369132                          0.01406
# 1                         0.369132                          0.01406
# 2                         0.369132                          0.01406
# 3                         0.369132                          0.01406
# 4                         0.369132                          0.01406
#
#    prev_max_load_centrality  prev_avg_load_centrality  \
# 0                  0.367384                   0.01406
# 1                  0.367384                   0.01406
# 2                  0.367384                   0.01406
# 3                  0.367384                   0.01406
# 4                  0.367384                   0.01406
#
#    prev_max_closeness_centrality  prev_avg_closeness_centrality  \
# 0                       0.395384                       0.242961
# 1                       0.395384                       0.242961
# ...

# %% [markdown]
# ## 2d_2w cleanup

# %%
twoD_2W_pad_unclean = pd.read_csv("twoD_2W_df_unclean.csv")

# %%
twoD_2W_pad_unclean.head()
# Out:
#    Unnamed: 0  prev_max_betweenness_centrality  \
# 0           0                         0.369132
# 1           1                         0.369132
# 2           2                         0.369132
# 3           3                         0.369132
# 4           4                         0.369132
#
#    prev_avg_betweenness_centrality  prev_max_load_centrality  \
# 0                          0.01406                  0.367384
# 1                          0.01406                  0.367384
# 2                          0.01406                  0.367384
# 3                          0.01406                  0.367384
# 4                          0.01406                  0.367384
#
#    prev_avg_load_centrality  prev_max_closeness_centrality  \
# 0                   0.01406                       0.395384
# 1                   0.01406                       0.395384
# 2                   0.01406                       0.395384
# 3                   0.01406                       0.395384
# ...

# %%
td_cols_to_remove = ['Unnamed: 0', 'prev_is_anamoly', 'next_is_anamoly']
twoD_2W_pad_clean = twoD_2W_pad_unclean.drop(td_cols_to_remove, axis=1)

# %%
# Saving clean csvs
adj_2w_pad_clean.to_csv(r"adj_2w_pad_clean.csv")
oneD_2W_pad_clean.to_csv(r"oneD_2W_df_clean.csv")
twoD_2W_pad_clean.to_csv(r"twoD_2W_df_clean.csv")
